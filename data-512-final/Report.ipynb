# %% [markdown]
# ### Abstract

# %% [markdown]
# This analysis is about exploring fake news using the FakeNewsNet dataset. In particular, I determine the most common words and websites used in fake vs real news. My results have strong implications for journalists and users. This work can be improved by using a larger dataset for richer analysis.

# %% [markdown]
# ### Introduction

# %% [markdown]
# For my final project, I want to dig deeper into fake news. This is a topic that has gained a lot of traction recently and I would like to explore what constitutes fake news as well as the dissemination in social media. From a human centered perspective, fake news has dire consequences. With the growing dependence on smartphones, more individiauls read their news on social media and, hence, viral fake news can influence people wrongly. Through this analysis, I hope to learn the characteristics or features that identify news as fake as well as discover the websites that are guilty of sharing fake news.

# %% [markdown]
# ### Data

# %% [markdown]
# For this analysis, I will be using FakeNewsNet - a data repository with news content, social context, and spatiotemporal information for studying fake news on social media. The repository can be found at https://github.com/KaiDMML/FakeNewsNet and the paper at https://arxiv.org/abs/1809.01286. FakeNewsNet contains 2 datasets collected using ground truths from Politifact and Gossipcop. Each source contributes one csv for fake news and the other real news. I wil focus on the two Politifact csv's. Each of the CSV files is comma separated file and have the following columns:
# 1. id - Unique identifider for each news
# 2. url - Url of the article from web that published that news
# 3. title - Title of the news article
# 4. tweet_ids - Tweet ids of tweets sharing the news. This field is list of tweet ids separated by tab.
#
# With this dataset, I wil be able to compare the fake news and real news.

# %% [markdown]
# ### Related Work

# %% [markdown]
# There has been alot of work to distinguish between fake news and real news. For instance, Eliza Shoemaker created a tool for automating the detection of Fake News by identifying which features are more useful for different classifiers (Using data science to detect fake news, 2019). Similary, there has been many projects and repositories to build such classifiers. TowardsDataScience published an article which uses Recurrent Neural Networks to detect fake news (https://towardsdatascience.com/building-a-fake-news-classifier-using-natural-language-processing-83d911b237e1).

# %% [markdown]
# ### Research Questions

# %% [markdown]
# 1. Which terms are most strongly associated with fake vs real news?
# 2. Which websites are most strongly associated with fake vs real news?

# %% [markdown]
# ### Methodology

# %% [markdown]
# Import the packages used for this analysis.

# %%
import pandas as pd
from collections import Counter
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# We start by tackling research question 1 and the Politifact fake news dataset.

# %%
#Read dataset
politic_fake = pd.read_csv('./data/dataset/politifact_fake.csv')

# %%
#Explore data
print(politic_fake.shape)
politic_fake.head()
# Out:
# (432, 4)
#                 id                                           news_url  \
# 0  politifact15014          speedtalk.com/forum/viewtopic.php?t=51650
# 1  politifact15156  politics2020.info/index.php/2018/03/13/court-o...
# 2  politifact14745  www.nscdscamps.org/blog/category/parenting/467...
# 3  politifact14355  https://howafrica.com/oscar-pistorius-attempts...
# 4  politifact15371  http://washingtonsources.org/trump-votes-for-d...
#
#                                                title  \
# 0  BREAKING: First NFL Team Declares Bankruptcy O...
# 1  Court Orders Obama To Pay $400 Million In Rest...
# 2  UPDATE: Second Roy Moore Accuser Works For Mic...
# 3         Oscar Pistorius Attempts To Commit Suicide
# 4        Trump Votes For Death Penalty For Being Gay
#
#                                            tweet_ids
# 0  937349434668498944\t937379378006282240\t937380...
# 1  972666281441878016\t972678396575559680\t972827...
# 2  929405740732870656\t929439450400264192\t929439...
# 3  886941526458347521\t887011300278194176\t887023...
# 4  915205698212040704\t915242076681506816\t915249...

# %% [markdown]
# The first step is to clean all the titles and combine the text. This includes removing non alphabetic characters and converting all words to lower case.

# %%
#Remove non alphabetic characters
sms = re.sub('[^A-Za-z]', ' ', str(politic_fake['title']))

# %%
#Make the words lower case
sms = sms.lower()

# %% [markdown]
# The next step is to remove any stopwords. To do this, we first tokenize the words.

# %%
#Tokenize words
nltk.download('punkt')
tokenized_sms = word_tokenize(sms)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kusht\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Remove stop words
nltk.download('stopwords')

for word in tokenized_sms:
    if word in stopwords.words('english'):
        tokenized_sms.remove(word)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kusht\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Now that we have our titles cleaned and tokenzed, we can count the occurence of each word and store the counts in a dictionary.

# %%
counts = {}
for i in tokenized_sms:
    if i not in counts:
        counts[i] = 0
    counts[i] = counts[i] + 1

# %% [markdown]
# Finally, we use Counter to determine the most common words in the all titles.

# %%
d = Counter(counts)
d.most_common()
# Out:
# [('trump', 10),
#  ('breaking', 8),
#  ('obama', 7),
#  ('clinton', 4),
#  ('donald', 4),
#  ('court', 3),
#  ('new', 3),
#  ('george', 3),
#  ('arrested', 3),
#  ('the', 3),
#  ('suicide', 2),
#  ('death', 2),
#  ('pope', 2),
#  ('francis', 2),
#  ('man', 2),
#  ('york', 2),
#  ('men', 2),
#  ('hillary', 2),
#  ('president', 2),
#  ('us', 2),
#  ('issued', 2),
#  ('snapchat', 2),
#  ('t', 2),
#  ('official', 2),
#  ('c', 2),
#  ('arrest', 2),
#  ('america', 2),
#  ('account', 2),
#  ('suspended', 2),
#  ('police', 2),
#  ('a', 2),
#  ('first', 1),
#  ('nfl', 1),
#  ('team', 1),
#  ('declares', 1),
#  ('bankruptcy', 1),
#  ('orders', 1),
#  ('pay', 1),
#  ('million', 1),
#  ('rest', 1),
#  ('update', 1),
#  ('second', 1),
#  ('roy', 1),
#  ('moore', 1),
#  ('accuser', 1),
#  ('works', 1),
#  ('mic', 1),
#  ('oscar', 1),
#  ('pistorius', 1),
#  ('attempts', 1),
#  ('commit', 1),
#  ('votes', 1),
#  ('penalty', 1),
#  ('gay', 1),
#  ('putin', 1),
#  ('says', 1),
#  ('not', 1),
#  ('god', 1),
#  ('wanted', 1),
#  ('infecting', 1),
#  ('saudi', 1),
#  ('arabia', 1),
#  ('behead', 1),
#  ('school', 1),
#  ('girls', 1),
#  ('bein', 1),
#  ('malia', 1),
#  ('fired', 1),
#  ('cushy', 1),
#  ('internship', 1),
#  ('spa', 1),
#  ('target', 1),
#  ('discontinue', 1),
#  ('sale', 1),
#  ('holy', 1),
#  ('bible', 1),
#  ('youngest', 1),
#  ('world', 1),
#  ('leader', 1),
#  ('bans', 1),
#  ('soros', 1),
#  ('foun', 1),
#  ('third', 1),
#  ('heart', 1),
#  ('atta', 1),
#  ('barack', 1),
#  ('tweets', 1),
#  ('sick', 1),
#  ('attack', 1),
#  ('john', 1),
#  ('mccain', 1),
#  ('underscores', 1),
#  ('jamaica', 1),
#  ('relations', 1),
#  ('actress', 1),
#  ('sandra', 1),
#  ('bullock', 1),
#  ('y', 1),
#  ('gretchen', 1),
#  ('carlson', 1),
#  ('nd', 1),
#  ('amendment', 1),
#  ('writt', 1),
#  ('mass', 1),
#  ('jesus', 1),
#  ('metaphorical', 1),
#  ('black', 1),
#  ('philadelphia', 1),
#  ('starbucks', 1),
#  ('ice', 1),
#  ('detainer', 1),
#  ('suspected', 1),
#  ('wine', 1),
#  ('country', 1),
#  ('former', 1),
#  ('presidents', 1),
#  ('walk', 1),
#  ('fine', 1),
#  ('line', 1),
#  ('am', 1),
#  ('inside', 1),
#  ('bloodbath', 1),
#  ('minutes', 1),
#  ('nancy', 1),
#  ('pelosi', 1),
#  ('resign', 1),
#  ('rev', 1),
#  ('inauguration', 1),
#  ('artists', 1),
#  ('won', 1),
#  ('p', 1),
#  ('leaked', 1),
#  ('picture', 1),
#  ('being', 1),
#  ('dragge', 1),
#  ('campaign', 1),
#  ('fbi', 1),
#  ('train', 1),
#  ('news', 1),
#  ('rosa', 1),
#  ('parks', 1),
#  ('grand', 1),
#  ('nra', 1),
#  ('jim', 1),
#  ('porter', 1),
#  ('falsely', 1),
#  ('accused', 1),
#  ('sa', 1),
#  ('biden', 1),
#  ('raises', 1),
#  ('possibility', 1),
#  ('presidential', 1),
#  ('bid', 1),
#  ('nyc', 1),
#  ('physician', 1),
#  ('wife', 1),
#  ('jump', 1),
#  ('leave', 1),
#  ('ki', 1),
#  ('shutting', 1),
#  ('usda', 1),
#  ('approves', 1),
#  ('slaughterhouses', 1),
#  ('producing', 1),
#  ('horse', 1),
#  ('delta', 1),
#  ('force', 1),
#  ('raids', 1),
#  ('stronghold', 1),
#  ('thailand', 1),
#  ('accessed', 1),
#  ('aug', 1),
#  ('bowe', 1),
#  ('bergdahl', 1),
#  ('wanders', 1),
#  ('during', 1),
#  ('martial', 1),
#  ('iranian', 1),
#  ('drops', 1),
#  ('bombshell', 1),
#  ('secret', 1),
#  ('isis', 1),
#  ('lays', 1),
#  ('arms', 1),
#  ('katy', 1),
#  ('perry', 1),
#  ('impassi', 1),
#  ('supreme', 1),
#  ('sides', 1),
#  ('barron', 1),
#  ('rushed', 1),
#  ('hospital', 1),
#  ('international', 1),
#  ('warrant', 1),
#  ('h', 1),
#  ('w', 1),
#  ('bush', 1),
#  ('died', 1),
#  ('keanu', 1),
#  ('travel', 1),
#  ('ban', 1),
#  ('terrible', 1),
#  ('wake', 1),
#  ('discover', 1),
#  ('meth', 1),
#  ('lab', 1),
#  ('back', 1),
#  ('room', 1),
#  ('alaba', 1),
#  ('florida', 1),
#  ('passes', 1),
#  ('bill', 1),
#  ('legalizing', 1),
#  ('recreational', 1),
#  ('twitter', 1),
#  ('caught', 1),
#  ('leaking', 1),
#  ('private', 1),
#  ('senate', 1),
#  ('report', 1),
#  ('admits', 1),
#  ('gifted', 1),
#  ('children', 1),
#  ('rubio', 1),
#  ('rape', 1),
#  ('victims', 1),
#  ('be', 1),
#  ('custody', 1),
#  ('radical', 1),
#  ('muslims', 1),
#  ('australia', 1),
#  ('offended', 1),
#  ('rep', 1),
#  ('paul', 1),
#  ('gosar', 1),
#  ('asks', 1),
#  ('capitol', 1),
#  ('worse', 1),
#  ('hitler', 1),
#  ('trey', 1),
#  ('gowdy', 1),
#  ('son', 1),
#  ('found', 1),
#  ('protester', 1),
#  ('speaks', 1),
#  ('i', 1),
#  ('paid', 1),
#  ('liberal', 1),
#  ('celebrities', 1),
#  ('singer', 1),
#  ('dolly', 1),
#  ('parton', 1),
#  ('one', 1),
#  ('year', 1),
#  ('alr', 1),
#  ('busted', 1),
#  ('russian', 1),
#  ('mansions', 1),
#  ('seized', 1),
#  ('mea', 1),
#  ('is', 1),
#  ('affected', 1),
#  ('government', 1),
#  ('shutdown', 1),
#  ('lindsey', 1),
#  ('graham', 1),
#  ('threatens', 1),
#  ('convert', 1),
#  ('democra', 1),
#  ('electoral', 1),
#  ('college', 1),
#  ('elector', 1),
#  ('commits', 1),
#  ('sarah', 1),
#  ('palin', 1),
#  ('calls', 1),
#  ('boycott', 1),
#  ('mall', 1),
#  ('b', 1),
#  ('name', 1),
#  ('title', 1),
#  ('length', 1),
#  ('dtype', 1),
#  ('object', 1)]

# %% [markdown]
# We repeat this process but for the Politifact real news dataset.

# %%
politic_real = pd.read_csv('./data/dataset/politifact_real.csv')

# %%
print(politic_real.shape)
politic_real.head()
# Out:
# (624, 4)
#                 id                                           news_url  \
# 0  politifact14984                          http://www.nfib-sbet.org/
# 1  politifact12944  http://www.cq.com/doc/newsmakertranscripts-494...
# 2    politifact333  https://web.archive.org/web/20080204072132/htt...
# 3   politifact4358  https://web.archive.org/web/20110811143753/htt...
# 4    politifact779  https://web.archive.org/web/20070820164107/htt...
#
#                                                title  \
# 0        National Federation of Independent Business
# 1                        comments in Fayetteville NC
# 2  Romney makes pitch, hoping to close deal : Ele...
# 3  Democratic Leaders Say House Democrats Are Uni...
# 4    Budget of the United States Government, FY 2008
#
#                                            tweet_ids
# 0  967132259869487105\t967164368768196609\t967215...
# 1  942953459\t8980098198\t16253717352\t1668513250...
# 2                                                NaN
# 3                                                NaN
# 4  89804710374154240\t91270460595109888\t96039619...

# %%
#Remove non alphabetic characters
import re
sms = re.sub('[^A-Za-z]', ' ', str(politic_real['title']))

# %%
#Make the word lower case
sms = sms.lower()

# %%
#Tokenize words
import nltk

nltk.download('punkt')
from nltk.tokenize import word_tokenize

tokenized_sms = word_tokenize(sms)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kusht\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Remove stop words
nltk.download('stopwords')
from nltk.corpus import stopwords 

for word in tokenized_sms:
    if word in stopwords.words('english'):
        tokenized_sms.remove(word)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kusht\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
counts = {}
for i in tokenized_sms:
    if i not in counts:
        counts[i] = 0
    counts[i] = counts[i] + 1

# %%
d = Counter(counts)
d.most_common()
# Out:
# [('the', 7),
#  ('says', 5),
#  ('democratic', 4),
#  ('transcript', 4),
#  ('house', 3),
#  ('trump', 3),
#  ('political', 3),
#  ('health', 3),
#  ('hillary', 3),
#  ('clinton', 3),
#  ('sanders', 3),
#  ('debate', 3),
#  ('national', 2),
#  ('comments', 2),
#  ('budget', 2),
#  ('affordable', 2),
#  ('gop', 2),
#  ('stop', 2),
#  ('statistics', 2),
#  ('care', 2),
#  ('week', 2),
#  ('impeachment', 2),
#  ('rand', 2),
#  ('paul', 2),
#  ('u', 2),
#  ('senate', 2),
#  ('show', 2),
#  ('report', 2),
#  ('bernie', 2),
#  ('tax', 2),
#  ('senator', 2),
#  ('group', 2),
#  ('federation', 1),
#  ('independent', 1),
#  ('business', 1),
#  ('fayetteville', 1),
#  ('nc', 1),
#  ('romney', 1),
#  ('makes', 1),
#  ('pitch', 1),
#  ('hoping', 1),
#  ('close', 1),
#  ('deal', 1),
#  ('ele', 1),
#  ('leaders', 1),
#  ('say', 1),
#  ('democrats', 1),
#  ('uni', 1),
#  ('united', 1),
#  ('states', 1),
#  ('government', 1),
#  ('fy', 1),
#  ('donald', 1),
#  ('exaggerates', 1),
#  ('china', 1),
#  ('ha', 1),
#  ('th', 1),
#  ('amendment', 1),
#  ('briefing', 1),
#  ('white', 1),
#  ('press', 1),
#  ('secretary', 1),
#  ('robert', 1),
#  ('solar', 1),
#  ('grand', 1),
#  ('plan', 1),
#  ('scientific', 1),
#  ('american', 1),
#  ('covering', 1),
#  ('young', 1),
#  ('adults', 1),
#  ('car', 1),
#  ('harry', 1),
#  ('reid', 1),
#  ('crying', 1),
#  ('tv', 1),
#  ('ad', 1),
#  ('archive', 1),
#  ('polad', 1),
#  ('bureau', 1),
#  ('labor', 1),
#  ('data', 1),
#  ('summary', 1),
#  ('act', 1),
#  ('holder', 1),
#  ('giuliani', 1),
#  ('talk', 1),
#  ('becomes', 1),
#  ('cynical', 1),
#  ('game', 1),
#  ('preventing', 1),
#  ('flu', 1),
#  ('good', 1),
#  ('habits', 1),
#  ('hel', 1),
#  ('las', 1),
#  ('vegas', 1),
#  ('campaign', 1),
#  ('rally', 1),
#  ('moveon', 1),
#  ('org', 1),
#  ('action', 1),
#  ('things', 1),
#  ('know', 1),
#  ('campaigns', 1),
#  ('iowa', 1),
#  ('miller', 1),
#  ('meeks', 1),
#  ('hispanic', 1),
#  ('populations', 1),
#  ('share', 1),
#  ('wealth', 1),
#  ('likely', 1),
#  ('guns', 1),
#  ('exceed', 1),
#  ('next', 1),
#  ('nine', 1),
#  ('cat', 1),
#  ('already', 1),
#  ('lost', 1),
#  ('decade', 1),
#  ('working', 1),
#  ('age', 1),
#  ('household', 1),
#  ('supreme', 1),
#  ('court', 1),
#  ('nominations', 1),
#  ('presen', 1),
#  ('politifact', 1),
#  ('annotated', 1),
#  ('secon', 1),
#  ('obamas', 1),
#  ('capandtrade', 1),
#  ('costs', 1),
#  ('des', 1),
#  ('moines', 1),
#  ('register', 1),
#  ('tonight', 1),
#  ('jay', 1),
#  ('leno', 1),
#  ('pelosi', 1),
#  ('gates', 1),
#  ('colbert', 1),
#  ('coddling', 1),
#  ('super', 1),
#  ('rich', 1),
#  ('vote', 1),
#  ('background', 1),
#  ('che', 1),
#  ('families', 1),
#  ('facing', 1),
#  ('increases', 1),
#  ('ta', 1),
#  ('geithners', 1),
#  ('issues', 1),
#  ('begins', 1),
#  ('amid', 1),
#  ('calls', 1),
#  ('fo', 1),
#  ('updated', 1),
#  ('facts', 1),
#  ('emails', 1),
#  ('republicans', 1),
#  ('t', 1),
#  ('maybe', 1),
#  ('brave', 1),
#  ('eno', 1),
#  ('sen', 1),
#  ('warns', 1),
#  ('frightening', 1),
#  ('trend', 1),
#  ('towa', 1),
#  ('latest', 1),
#  ('news', 1),
#  ('headlines', 1),
#  ('d', 1),
#  ('cleveland', 1),
#  ('rick', 1),
#  ('perry', 1),
#  ('he', 1),
#  ('switched', 1),
#  ('younge', 1),
#  ('rodham', 1),
#  ('new', 1),
#  ('york', 1),
#  ('socialism', 1),
#  ('cnn', 1),
#  ('miami', 1),
#  ('republican', 1),
#  ('barack', 1),
#  ('obama', 1),
#  ('oil', 1),
#  ('production', 1),
#  ('last', 1),
#  ('yea', 1),
#  ('survey', 1),
#  ('results', 1),
#  ('hays', 1),
#  ('research', 1),
#  ('economic', 1),
#  ('outlook', 1),
#  ('fiscal', 1),
#  ('years', 1),
#  ('testimony', 1),
#  ('submitted', 1),
#  ('congressional', 1),
#  ('overs', 1),
#  ('remarks', 1),
#  ('president', 1),
#  ('economy', 1),
#  ('kno', 1),
#  ('daily', 1),
#  ('trevor', 1),
#  ('noah', 1),
#  ('historical', 1),
#  ('aggregate', 1),
#  ('income', 1),
#  ('fifths', 1),
#  ('top', 1),
#  ('hint', 1),
#  ('stirs', 1),
#  ('clash', 1),
#  ('obameter', 1),
#  ('introduce', 1),
#  ('a', 1),
#  ('comprehensive', 1),
#  ('immigr', 1),
#  ('asking', 1),
#  ('congress', 1),
#  ('mexico', 1),
#  ('pay', 1),
#  ('flake', 1),
#  ('religious', 1),
#  ('tests', 1),
#  ('have', 1),
#  ('place', 1),
#  ('change', 1),
#  ('can', 1),
#  ('believe', 1),
#  ('deputy', 1),
#  ('director', 1),
#  ('romneys', 1),
#  ('prolife', 1),
#  ('conversion', 1),
#  ('myth', 1),
#  ('reality', 1),
#  ('jun', 1),
#  ('interest', 1),
#  ('ratings', 1),
#  ('name', 1),
#  ('title', 1),
#  ('length', 1),
#  ('dtype', 1),
#  ('object', 1)]

# %% [markdown]
# To tackle research question 2, we analyze the news_urls. Again, we start with the Politifact fake news dataset. We parse the website name by splitting the news_url string on '/'. We use an IF statement to account for the different patterns of the news_url stored. Finally, we store these websites in a dictionary along with their frequeny.

# %%
counts = {}
for i in politic_fake['news_url']:
    if i == i: #to account for news_url that are Nan
        split = i.split('/')
        if split[0] == 'http:' or split[0] == 'https:':
            if split[2] not in counts:
                counts[split[2]] = 0
            counts[split[2]] = counts[split[2]] + 1
        else:
            if split[0] not in counts:
                counts[split[0]] = 0
            counts[split[0]] = counts[split[0]] + 1

# %% [markdown]
# Finally, we use Counter to determine the most common websites.

# %%
d = Counter(counts)
d.most_common()
# Out:
# [('web.archive.org', 69),
#  ('yournewswire.com', 15),
#  ('www.facebook.com', 6),
#  ('www.thegatewaypundit.com', 5),
#  ('dailyfeed.news', 4),
#  ('thehill.com', 4),
#  ('worldnewsdailyreport.com', 4),
#  ('www.react365.com', 4),
#  ('www.washingtonpost.com', 4),
#  ('me.me', 3),
#  ('www.breitbart.com', 3),
#  ('www.breakingnews365.net', 3),
#  ('www.cnn.com', 3),
#  ('www.newsweek.com', 3),
#  ('www.usacarry.com', 3),
#  ('politicot.com', 3),
#  ('www.neonnettle.com', 3),
#  ('dailyworldupdate.us', 3),
#  ('www.trendolizer.com', 3),
#  ('observeronline.news', 3),
#  ('www.usatoday.com', 3),
#  ('our.news', 3),
#  ('therightists.com', 2),
#  ('www.politico.com', 2),
#  ('nrtonline.info', 2),
#  ('www.puppetstringnews.com', 2),
#  ('newsbreakshere.com', 2),
#  ('nyeveningnews.com', 2),
#  ('www.newslo.com', 2),
#  ('www.nbcnews.com', 2),
#  ('obama.trendolizer.com', 2),
#  ('flashnewss.club', 2),
#  ('eveningw.com', 2),
#  ('theglobalheadlines.net', 2),
#  ('americannews.com', 2),
#  ('mainerepublicemailalert.com', 2),
#  ('www.bbc.com', 2),
#  ('notallowedto.com', 2),
#  ('nypost.com', 2),
#  ('conservativedailypost.com', 2),
#  ('www.politifact.com', 2),
#  ('theseattletribune.com', 2),
#  ('rip.trendolizer.com', 2),
#  ('babylonbee.com', 2),
#  ('usleader.net', 2),
#  ('www.foxnews.com', 2),
#  ('disaster.trendolizer.com', 2),
#  ('freedomdaily.com', 2),
#  ('www.breakingnews247.net', 2),
#  ('empirenews.net', 2),
#  ('politicono.com', 2),
#  ('speedtalk.com', 1),
#  ('politics2020.info', 1),
#  ('www.nscdscamps.org', 1),
#  ('howafrica.com', 1),
#  ('washingtonsources.org', 1),
#  ('gloria.tv', 1),
#  ('blogs.trendolizer.com', 1),
#  ('beforeitsnews.com', 1),
#  ('jis.gov.jm', 1),
#  ('www.mirror.co.uk', 1),
#  ('www.independent.co.uk', 1),
#  ('usaconservativereport.com', 1),
#  ('donaldtrainews.blogspot.com', 1),
#  ('urbanintellectuals.com', 1),
#  ('quickening-spirit.com', 1),
#  ('pegida.trendolizer.com', 1),
#  ('econewsmedia.org', 1),
#  ('www.smoaky.com', 1),
#  ('londonwebnews.com', 1),
#  ('www.thesun.co.uk', 1),
#  ('www.ravinderbhalla.com', 1),
#  ('sentinelksmo.org', 1),
#  ('lidblog.com', 1),
#  ('www.christforums.org', 1),
#  ('now8news.com', 1),
#  ('mysteriousearth.club', 1),
#  ('www.haaretz.com', 1),
#  ('exclusive103.com', 1),
#  ('www.theguardian.com', 1),
#  ('sportfella.com', 1),
#  ('www.house.gov', 1),
#  ('emsnews.wordpress.com', 1),
#  ('teddystick.com', 1),
#  ('www.pirate4x4.com', 1),
#  ('hotgazette.com', 1),
#  ('www.nyfoxnews.co', 1),
#  ('usnnetwork.com', 1),
#  ('www.firstpost.com', 1),
#  ('www.vox.com', 1),
#  ('www.newsdonaldtrumps.com', 1),
#  ('sciencevibe.com', 1),
#  ('medium.com', 1),
#  ('mightynest.com', 1),
#  ('www.chicagosuntimes.live', 1),
#  ('patriotcrier.com', 1),
#  ('www.bluedotdaily.com', 1),
#  ('actionnetwork.org', 1),
#  ('maga2020.us', 1),
#  ('conservativetown.com', 1),
#  ('viraldevil.com', 1),
#  ('www.tdtalliance.com', 1),
#  ('www.empiresports.co', 1),
#  ('www.youtube.com', 1),
#  ('polls.trendolizer.com', 1),
#  ('usamirrornews.com', 1),
#  ('halfwaypost.com', 1),
#  ('www.pewtrusts.org', 1),
#  ('reflectionofmind.org', 1),
#  ('wkrg.com', 1),
#  ('www.viralwdc.site', 1),
#  ('www.conservativestories.com', 1),
#  ('realtimepolitics.com', 1),
#  ('portalstate.com', 1),
#  ('uspostman.com', 1),
#  ('jumboreport.com', 1),
#  ('majorthoughts.com', 1),
#  ('realnewsrightnow.com', 1),
#  ('dailybuzzlive.com', 1),
#  ('twitter.com', 1),
#  ('politicsdepot.com', 1),
#  ('www.viraltruthwire.com', 1),
#  ('politifeed.net', 1),
#  ('www.usnews.com', 1),
#  ('smag31.com', 1),
#  ('what-you-missed.com', 1),
#  ('viralactions.com', 1),
#  ('www.thecommonsenseshow.com', 1),
#  ('www.zambianobserver.com', 1),
#  ('fellowshipoftheminds.com', 1),
#  ('www.theburningplatform.com', 1),
#  ('www.truthexam.com', 1),
#  ('politicalmayhem.news', 1),
#  ('www.rollingstone.com', 1),
#  ('www.higherperspectives.com', 1),
#  ('nymag.com', 1),
#  ('www.veterantv.com', 1),
#  ('ourvoiceny.com', 1),
#  ('freeinfomedia.com', 1),
#  ('usawatchdog.com', 1),
#  ('gellerreport.com', 1),
#  ('www.lovethispic.com', 1),
#  ('smartmindmag.com', 1),
#  ('www.sfchronicle.com', 1),
#  ('www.cpsc.gov', 1),
#  ('www.proxywhore.com', 1),
#  ('www.neon-nettle.com', 1),
#  ('alternativemediasyndicate.com', 1),
#  ('politicass.com', 1),
#  ('flashnewscorner.com', 1),
#  ('channel24news.com', 1),
#  ('usanews24h.tk', 1),
#  ('wesupportdonaldtrump.com', 1),
#  ('www.thelifebuzz.com', 1),
#  ('gunrights.trendolizer.com', 1),
#  ('www.nytimes.com', 1),
#  ('usa24info.com', 1),
#  ('www.fda.gov', 1),
#  ('activistmommy.com', 1),
#  ('the-fringe.com', 1),
#  ('www.alison-jackson.co.uk', 1),
#  ('twentyeightmay.pw', 1),
#  ('24trueinfoamerica.com', 1),
#  ('usalibertypress.com', 1),
#  ('www.unseen-pedia.com', 1),
#  ('www.cvikas.com', 1),
#  ('www.worldfactsftw.com', 1),
#  ('allnews4us.com', 1),
#  ('www.patriotnetwork.one', 1),
#  ('conservative7.com', 1),
#  ('www.justice.gov', 1),
#  ('forfreedomworld.com', 1),
#  ('usbreakingnews.net', 1),
#  ('revolutionradio.org', 1),
#  ('steemit.com', 1),
#  ('houstonpost.co', 1),
#  ('www.wilmingtonfilm.com', 1),
#  ('unofficialnetworks.com', 1),
#  ('proudleader.com', 1),
#  ('www.projectrepublictoday.com', 1),
#  ('forums.spacebattles.com', 1),
#  ('www.helloforos.com', 1),
#  ('madworldnews.com', 1),
#  ('www.unilad.co.uk', 1),
#  ('www.huzlers.com', 1),
#  ('proconservativenews.com', 1),
#  ('redstatewave.com', 1),
#  ('www.occupydemocrats.com', 1),
#  ('www.inverse.com', 1),
#  ('www.inspiringday.com', 1),
#  ('pix11.com', 1),
#  ('www.ecfr.gov', 1),
#  ('time.com', 1),
#  ('inshapetoday.com', 1),
#  ('redstatewatcher.com', 1),
#  ('newsuptoday.com', 1),
#  ('info.nct.news', 1),
#  ('thenationalmarijuananews.com', 1),
#  ('www.libertyheadlines.com', 1),
#  ('www.whathappensintheusa.com', 1),
#  ('www.businessinsider.com', 1),
#  ('breaking13news.com', 1),
#  ('straightstoned.com', 1),
#  ('dailyheadlines.net', 1),
#  ('www.americatb.com', 1),
#  ('www.masscops.com', 1),
#  ('zimbabwe-today.com', 1),
#  ('daily-vine.com', 1),
#  ('news.antiwar.com', 1),
#  ('conservativepost.com', 1),
#  ('www.blingnews.com', 1),
#  ('www.theverge.com', 1),
#  ('asnowrose.wordpress.com', 1),
#  ('news.groopspeak.com', 1),
#  ('100percentfedup.com', 1),
#  ('www.infowars.com', 1),
#  ('usanewscentral.com', 1),
#  ('www.newscats.org', 1),
#  ('wrpm33.com', 1),
#  ('tmzbreaking.com', 1),
#  ('www2.alabamavotes.gov', 1),
#  ('theeconomiccollapseblog.com', 1),
#  ('www.geopolitica.ru', 1),
#  ('dailynative.us', 1),
#  ('www.disclose.tv', 1),
#  ('thegoldwater.com', 1),
#  ('vote.us.org', 1),
#  ('ghanaweb.website', 1),
#  ('www.mysterious-times.com', 1),
#  ('actionnews3.com', 1),
#  ('trueamericans.me', 1),
#  ('newsfeedobserver.com', 1),
#  ('homelessholocaust.wordpress.com', 1),
#  ('wazanews.tk', 1),
#  ('www.zerohedge.com', 1),
#  ('www.archives.gov', 1),
#  ('conservative-headlines.com', 1),
#  ('www.opreminfo.com', 1),
#  ('washingtonpress.com', 1),
#  ('www.thebreakingdawn.site', 1),
#  ('www.ajeteys.com', 1),
#  ('christmasdailygifts.info', 1),
#  ('policetimes.info', 1),
#  ('usanewstoday.org', 1),
#  ('maxipolitics.com', 1),
#  ('boingboing.net', 1),
#  ('www.hollywoodreporter.com', 1),
#  ('www.reddit.com', 1),
#  ('www.fox5dc.com', 1),
#  ('www.newsfeedusa.us', 1),
#  ('newstarget.com', 1),
#  ('www.someonesbones.com', 1),
#  ('www.rearfront.com', 1),
#  ('www.duffelblog.com', 1),
#  ('diamondandsilk.americandailynews.org', 1),
#  ('nowtrump.com', 1),
#  ('patrioticviralnews.com', 1),
#  ('nytiwes.com', 1),
#  ('www.apnews.com', 1),
#  ('bitcoingrower.life', 1),
#  ('www.abcnews-us.com', 1),
#  ('ladylibertysnews.com', 1),
#  ('www.trainnews.info', 1),
#  ('genius.com', 1),
#  ('miamipost.co', 1),
#  ('www.americanproud.info', 1),
#  ('archive.is', 1)]

# %% [markdown]
# We repeat this process for the Politifact real news dataset.

# %%
counts = {}
for i in politic_real['news_url']:
    if i == i: #to account for news_url that are Nan
        split = i.split('/')
        if split[0] == 'http:' or split[0] == 'https:':
            if split[2] not in counts:
                counts[split[2]] = 0
            counts[split[2]] = counts[split[2]] + 1
        else:
            if split[0] not in counts:
                counts[split[0]] = 0
            counts[split[0]] = counts[split[0]] + 1

# %%
d = Counter(counts)
d.most_common()
# Out:
# [('web.archive.org', 127),
#  ('www.youtube.com', 45),
#  ('abcnews.go.com', 24),
#  ('www.nytimes.com', 22),
#  ('www.politifact.com', 21),
#  ('www.whitehouse.gov', 17),
#  ('www.cq.com', 13),
#  ('www.msnbc.msn.com', 13),
#  ('www.washingtonpost.com', 12),
#  ('www.foxnews.com', 11),
#  ('www.cnn.com', 10),
#  ('medium.com', 9),
#  ('twitter.com', 8),
#  ('www.senate.gov', 7),
#  ('transcripts.cnn.com', 7),
#  ('www.cbsnews.com', 6),
#  ('www.cbo.gov', 6),
#  ('www.politico.com', 5),
#  ('frwebgate.access.gpo.gov', 5),
#  ('thomas.loc.gov', 5),
#  ('politicaladarchive.org', 4),
#  ('data.bls.gov', 4),
#  ('www.nbcnews.com', 4),
#  ('www.cdc.gov', 4),
#  ('www.bls.gov', 4),
#  ('query.nytimes.com', 4),
#  ('time.com', 4),
#  ('cq.com', 4),
#  ('www.kff.org', 3),
#  ('www.bea.gov', 3),
#  ('my.barackobama.com', 3),
#  ('politifact.com', 3),
#  ('www.c-span.org', 3),
#  ('youtu.be', 2),
#  ('www.desmoinesregister.com', 2),
#  ('video.foxnews.com', 2),
#  ('www.taxpolicycenter.org', 2),
#  ('www.eia.gov', 2),
#  ('www.ilga.gov', 2),
#  ('www.facebook.com', 2),
#  ('www.colbertnation.com', 2),
#  ('edition.cnn.com', 2),
#  ('www.gpo.gov', 2),
#  ('sotu.blogs.cnn.com', 2),
#  ('berniesanders.com', 2),
#  ('thehill.com', 2),
#  ('politicalticker.blogs.cnn.com', 2),
#  ('www.time.com', 2),
#  ('www.census.gov', 2),
#  ('cbo.gov', 2),
#  ('www.govtrack.us', 2),
#  ('www.mtv.com', 2),
#  ('youtube.com', 2),
#  ('www.nfib-sbet.org', 1),
#  ('www.law.cornell.edu', 1),
#  ('americaneedsmitt.com', 1),
#  ('www.commonwealthfund.org', 1),
#  ('www.stlouisfed.org', 1),
#  ('www.epi.org', 1),
#  ('democrats-oversight.house.gov', 1),
#  ('apnews.com', 1),
#  ('blogs.rollcall.com', 1),
#  ('iqmediacorp.com', 1),
#  ('www.unhcr.org', 1),
#  ('pollingreport.com', 1),
#  ('www.boston.com', 1),
#  ('www.globalsecurity.org', 1),
#  ('www.mass.gov', 1),
#  ('www.gao.gov', 1),
#  ('minnesota.cbslocal.com', 1),
#  ('www.brighthorizons.com', 1),
#  ('www.armytimes.com', 1),
#  ('elsa.berkeley.edu', 1),
#  ('www.popularmechanics.com', 1),
#  ('www.reuters.com', 1),
#  ('www.motherjones.com', 1),
#  ('teddeutch.house.gov', 1),
#  ('www.ohioart.com', 1),
#  ('www.starbulletin.com', 1),
#  ('www.paul.senate.gov', 1),
#  ('www.nap.edu', 1),
#  ('www.greentechmedia.com', 1),
#  ('beta.criticalmention.com', 1),
#  ('www.votesmart.org', 1),
#  ('www.forbes.com', 1),
#  ('www.bloomberg.com', 1),
#  ('crime.chicagotribune.com', 1),
#  ('www.sasse.senate.gov', 1),
#  ('www.ed.gov', 1),
#  ('findarticles.com', 1),
#  ('nobelprize.org', 1),
#  ('alexander.senate.gov', 1),
#  ('w3.nexis.com', 1),
#  ('blogs.wsj.com', 1),
#  ('www.themoscowtimes.com', 1),
#  ('www.realclearpolitics.com', 1),
#  ('triblive.com', 1),
#  ('webcache.googleusercontent.com', 1),
#  ('bioguide.congress.gov', 1),
#  ('nymag.com', 1),
#  ('www.acton.org', 1),
#  ('www.fdic.gov', 1),
#  ('www.supremecourt.gov', 1),
#  ('stabenow.senate.gov', 1),
#  ('www.cuinsight.com', 1),
#  ('action.citizen.org', 1),
#  ('therightscoop.com', 1),
#  ('www.defenselink.mil', 1),
#  ('www.businessinsider.com', 1),
#  ('www.mittvmitt.com', 1),
#  ('elections.nytimes.com', 1),
#  ('www.unionleader.com', 1),
#  ('www.ssa.gov', 1),
#  ('documents.nytimes.com', 1),
#  ('www.legis.state.ak.us', 1),
#  ('www.radaronline.com', 1),
#  ('www.guttmacher.org', 1),
#  ('www.economist.com', 1),
#  ('us3.campaign-archive1.com', 1),
#  ('energycommerce.house.gov', 1),
#  ('foreign.senate.gov', 1),
#  ('www.citizenlink.org', 1),
#  ('www.pbs.org', 1),
#  ('www.documentcloud.org', 1),
#  ('america.aljazeera.com', 1),
#  ('rare.us', 1),
#  ('www.pollingreport.com', 1),
#  ('www.tampabay.com', 1),
#  ('thecaucus.blogs.nytimes.com', 1),
#  ('www.guardian.co.uk', 1),
#  ('www.ecfr.gov', 1),
#  ('transcriptswire.cq.com', 1),
#  ('www.state.gov', 1),
#  ('www.opensecrets.org', 1),
#  ('blogs.desmoinesregister.com', 1),
#  ('graphics.nra.org', 1),
#  ('www.doe.mass.edu', 1),
#  ('www.ams.usda.gov', 1),
#  ('www.msnbc.com', 1),
#  ('data.unhcr.org', 1),
#  ('www.huffingtonpost.com', 1),
#  ('clerk.house.gov', 1),
#  ('www.pewforum.org', 1),
#  ('wfpl.org', 1),
#  ('www.fedupthebook.com', 1),
#  ('docquery.fec.gov', 1),
#  ('latimesblogs.latimes.com', 1),
#  ('www.fsis.usda.gov', 1),
#  ('politics.blogs.foxnews.com', 1),
#  ('www.npr.org', 1),
#  ('www.aft.org', 1),
#  ('www.press.org', 1),
#  ('legis.wisconsin.gov', 1),
#  ('tonto.eia.doe.gov', 1),
#  ('evanjenkins.house.gov', 1),
#  ('www.rawstory.com', 1),
#  ('www.politicsdaily.com', 1),
#  ('www.thedailyshow.com', 1),
#  ('select.nytimes.com', 1),
#  ('www.flake.senate.gov', 1)]

# %% [markdown]
# ### Results

# %% [markdown]
# *Research question 1*

# %% [markdown]
# Most common fake news words: Trump, Breaking, Suicide, Death
#
# Most common real news words: Awards, Discuss, Critics, Star

# %% [markdown]
# *Research question 2*

# %% [markdown]
# Most common fake news websites: yournewswire, facebook, dailyfeed
#
# Most common real news websites: abcnews, nytimes, politifact

# %% [markdown]
# ### Conclusion

# %% [markdown]
# From the above results, we see that fake news uses many pronouns and attention grabbing words for clickbait. Such words lure users scrolling through Twitter to click on such articles. We see that fake news titles use dull words in comparison, as we see 'the' as the most common word. One implication is that this information can persuade journalists to use more exciting titles to compete with those of fake news.

# %% [markdown]
# Coming to research question 2, we see a stark difference between the websites sharing fake vs real news articles. This provides strong evidence to users to check the source of the article to disseminate a fake vs real article.

# %% [markdown]
# ### Limitations

# %% [markdown]
# One limitation of this analysis is that the dataset is small. Hence, the word counts for research question 1 are relatively low.
